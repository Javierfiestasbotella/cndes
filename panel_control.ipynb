# %%
import tkinter as tk
from tkinter import ttk
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import numpy as np

# Función para actualizar las gráficas
def actualizar_graficas():
    # Aquí debes agregar la lógica para actualizar las gráficas según los inputs
    pass

# Configuración del estilo futurista
style = ttk.Style()
style.theme_use("clam")  # Puedes experimentar con otros temas según tu preferencia
style.configure("TLabel", background="#3a3a3a", foreground="#ffffff", font=("Arial", 10))
style.configure("TButton", background="#007acc", foreground="#ffffff", font=("Arial", 10))

# Crear la ventana principal
root = tk.Tk()
root.title("Panel de Control")
root.configure(bg="#3a3a3a")  # Fondo azul oscuro

# Crear el contenedor de gráficas y ajustar el tamaño
fig, axs = plt.subplots(2, 2, figsize=(8, 6))  # Gráficas un poco más grandes
plt.subplots_adjust(wspace=0.5, hspace=0.5)  # Espacio entre gráficas

# Gráfica 1
axs[0, 0].plot([1, 2, 3, 4], [10, 5, 20, 15])
axs[0, 0].set_title('Gráfica 1')

# Gráfica 2
axs[0, 1].plot([1, 2, 3, 4], [5, 10, 15, 20])
axs[0, 1].set_title('Gráfica 2')

# Gráfica 3
axs[1, 0].plot([1, 2, 3, 4], [15, 5, 10, 25])
axs[1, 0].set_title('Gráfica 3')

# Gráfica 4
axs[1, 1].plot([1, 2, 3, 4], [20, 15, 5, 10])
axs[1, 1].set_title('Gráfica 4')

# Agregar las gráficas al contenedor
canvas = FigureCanvasTkAgg(fig, master=root)
canvas.draw()
canvas.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH, expand=1)

# Crear etiquetas y entradas para los inputs
etiqueta_input = ttk.Label(root, text="Selecciona gráfica:")
etiqueta_input.pack(pady=10)

input_grafica = ttk.Combobox(root, values=["Gráfica 1", "Gráfica 2", "Gráfica 3", "Gráfica 4"])
input_grafica.set("Gráfica 1")
input_grafica.pack(pady=10)

# Botón para actualizar las gráficas
boton_actualizar = ttk.Button(root, text="Actualizar Gráficas", command=actualizar_graficas)
boton_actualizar.pack(pady=10)

# Crear un tablero de botones a la derecha y ajustar el ancho
frame_botones = tk.Frame(root, bg="#3a3a3a", width=200)
frame_botones.pack(side=tk.RIGHT, fill=tk.Y)

# Agregar botones al tablero
for i in range(1, 10):
    btn = ttk.Button(frame_botones, text=f"Botón {i}", style="TButton")
    btn.pack(pady=5)

# Iniciar el bucle principal
root.mainloop()
